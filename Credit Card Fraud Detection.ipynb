# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings("ignore")
sns.set(style="whitegrid")

# %%
df = pd.read_csv(r"C:\Users\Isha Sharma\Desktop\fraud detection\creditcard.csv")

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.shape
# Out:
# (284807, 31)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (284807, 31)

# %%
round((df["Class"].value_counts()[1] / df.shape[0]) * 100, 2)
# Out:
# np.float64(0.17)

# %%
sns.countplot(x="Class", data=df)
plt.title("Transaction Class Distribution")
plt.xlabel("Class (0 = Legitimate, 1 = Fraud)")
plt.ylabel("Count")
plt.show()

# %%
(df["Class"].value_counts(normalize=True) * 100).plot(
    kind="bar",
    title="Percentage of Fraud and Legitimate Transactions",
    color="salmon"
)

plt.ylabel("Percentage")
plt.xlabel("Class")
plt.show()

# %%
df["Amount"].describe().astype(int)
# Out:
# count    284807
# mean         88
# std         250
# min           0
# 25%           5
# 50%          22
# 75%          77
# max       25691
# Name: Amount, dtype: int64

# %%
sns.histplot(np.log1p(df["Amount"]), bins=100, kde=True, color="green")
plt.title("Transaction Amount Distribution (Log Scale)")
plt.xlabel("Log(Amount + 1)")
plt.show()

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    data=df[df["Amount"] < 1000],
    x="Class",
    y="Amount"
)

plt.title("Amount vs Fraud Status")
plt.xlabel("Class (0=Legitimate, 1=Fraud)")
plt.ylabel("Amount")
plt.show()

# %%
df.columns
# Out:
# Index(['Time', 'V1', 'V2', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10',
#        'V11', 'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20',
#        'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount',
#        'Class'],
#       dtype='object')

# %%
df["Amount_log"] = np.log1p(df["Amount"])

# %%
(df["Amount"] < 0).sum()
# Out:
# np.int64(0)

# %%
df.head(2)
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
#
#         V27       V28  Amount  Class  Amount_log
# 0  0.133558 -0.021053  149.62      0    5.014760
# 1 -0.008983  0.014724    2.69      0    1.305626
#
# [2 rows x 32 columns]

# %%
frauds_per_time = df[df["Class"] == 1]["Time"].value_counts().sort_index()

plt.figure(figsize=(10,5))
plt.plot(frauds_per_time.index, frauds_per_time.values)

plt.xlabel("Time")
plt.ylabel("Number of Frauds")
plt.title("Fraud Transactions Over Time")
plt.grid(True)
plt.show()

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
top_amounts = df["Amount"].sort_values(ascending=False).head(10)

# %%
print(top_amounts)
# Out:
# 274771    25691.16
# 58465     19656.53
# 151296    18910.00
# 46841     12910.93
# 54018     11898.09
# 169457    11789.84
# 284249    10199.44
# 227921    10000.00
# 74699      8790.26
# 245474     8787.00
# Name: Amount, dtype: float64

# %%
top_amounts = df["Amount"].nlargest(10)
print(top_amounts)
# Out:
# 274771    25691.16
# 58465     19656.53
# 151296    18910.00
# 46841     12910.93
# 54018     11898.09
# 169457    11789.84
# 284249    10199.44
# 227921    10000.00
# 74699      8790.26
# 245474     8787.00
# Name: Amount, dtype: float64

# %%
Fraud_transactions = df[df["Class"] == 1]["Amount"].sort_values(ascending=False).head(10)

print(Fraud_transactions)
# Out:
# 176049    2125.87
# 6971      1809.68
# 249167    1504.93
# 89190     1402.16
# 81609     1389.56
# 95597     1354.25
# 199896    1335.00
# 10690     1218.89
# 249239    1096.99
# 233258     996.27
# Name: Amount, dtype: float64

# %%
fraud_types = df[df["Class"] == 1]

# %%
fraud_types["Class"].value_counts()
# Out:
# Class
# 1    492
# Name: count, dtype: int64

# %%
plt.figure(figsize=(8,5))
sns.boxplot(data=df[df["Amount"] < 1000], x="Class", y="Amount")
plt.title("Transaction Amount by Class")
plt.show()

# %%
corr = df[["Amount", "Amount_log", "Class"]].corr()

# %%
corr
# Out:
#               Amount  Amount_log     Class
# Amount      1.000000    0.552005  0.005632
# Amount_log  0.552005    1.000000 -0.008326
# Class       0.005632   -0.008326  1.000000

# %%
corr = df[["V1","V2","V3","V4","V5","Amount","Class"]].corr()

plt.figure(figsize=(8,6))
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")

plt.title("Correlation Matrix")
plt.show()

# %%
high_amount_fraud = df[
    (df["Class"] == 1) &
    (df["Amount"] > df["Amount"].median())
]

# %%
len(high_amount_fraud)
# Out:
# 221

# %%
high_amount_fraud.head()
# Out:
#          Time        V1        V2        V3        V4        V5        V6  \
# 623     472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920   4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108   6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6971   9064.0 -3.499108  0.258555 -4.489558  4.853894 -6.974522  3.628382
# 8845  12095.0 -4.727713  3.044469 -5.598354  5.928191 -2.190770 -1.529323
#
#             V7        V8        V9  ...       V22       V23       V24  \
# 623   0.325574 -0.067794 -0.270953  ...  0.435477  1.375966 -0.293803
# 4920  0.562320 -0.399147 -0.238253  ... -0.932391  0.172726 -0.087330
# 6108 -3.496197 -0.248778 -0.247768  ...  0.176968 -0.436207 -0.053502
# 6971  5.431271 -1.946734 -0.775680  ...  0.204817 -2.119007  0.170279
# 8845 -4.487422  0.916392 -1.307010  ...  0.254983  0.628843 -0.238128
#
#            V25       V26       V27       V28   Amount  Class  Amount_log
# ...

# %%
df["Class"].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
df_model = df.copy()

# %%
df_model.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V22       V23       V24       V25       V26  \
# 0  0.098698  0.363787  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1  0.085102 -0.255425  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2  0.247676 -1.514654  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3  0.377436 -1.387024  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
# 4 -0.270533  0.817739  ...  0.798278 -0.137458  0.141267 -0.206010  0.502292
#
# ...

# %%
categorical = []

numeric = [
    "Time", "Amount", "Amount_log",
    "V1", "V2", "V3", "V4", "V5", "V6", "V7",
    "V8", "V9", "V10", "V11", "V12", "V13", "V14",
    "V15", "V16", "V17", "V18", "V19", "V20",
    "V21", "V22", "V23", "V24", "V25", "V26",
    "V27", "V28"
]

# %%
y = df_model["Class"]
X = df_model.drop("Class", axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42,
    stratify=y
)

# %%
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric)
    ],
    remainder="drop"
)

# %%
pipeline = Pipeline([
    ("prep", preprocessor),
    ("clf", LogisticRegression(class_weight="balanced", max_iter=1000))
])

# %%
pipeline.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['Time', 'Amount',
#                                                    'Amount_log', 'V1', 'V2',
#                                                    'V3', 'V4', 'V5', 'V6', 'V7',
#                                                    'V8', 'V9', 'V10', 'V11',
#                                                    'V12', 'V13', 'V14', 'V15',
#                                                    'V16', 'V17', 'V18', 'V19',
#                                                    'V20', 'V21', 'V22', 'V23',
#                                                    'V24', 'V25', 'V26', 'V27', ...])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
y_pred = pipeline.predict(X_test)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.98      0.99     85295
#            1       0.07      0.88      0.12       148
#
#     accuracy                           0.98     85443
#    macro avg       0.53      0.93      0.56     85443
# weighted avg       1.00      0.98      0.99     85443

# %%
print(confusion_matrix(y_test, y_pred))
# Out:
# [[83440  1855]
#  [   18   130]]

# %%
accuracy = pipeline.score(X_test, y_test) * 100
print("Accuracy:", round(accuracy, 2), "%")
# Out:
# Accuracy: 97.81 %

# %%
joblib.dump(pipeline, "credit_card_fraud_model.pkl")
# Out:
# ['credit_card_fraud_model.pkl']
